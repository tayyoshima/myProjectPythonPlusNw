# %%
print("Hello")
# Out:
# Hello

# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.5 MB 3.2 MB/s eta 0:00:04
#     --------------------------------------- 0.3/11.5 MB 4.4 MB/s eta 0:00:03
#    - -------------------------------------- 0.5/11.5 MB 4.2 MB/s eta 0:00:03
#    -- ------------------------------------- 0.8/11.5 MB 4.8 MB/s eta 0:00:03
#    --- ------------------------------------ 1.0/11.5 MB 4.5 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.2/11.5 MB 4.6 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.5/11.5 MB 4.6 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.7/11.5 MB 4.6 MB/s eta 0:00:03
#    ------ --------------------------------- 1.9/11.5 MB 4.8 MB/s eta 0:00:03
#    ------- -------------------------------- 2.2/11.5 MB 4.8 MB/s eta 0:00:02
#    -------- ------------------------------- 2.4/11.5 MB 4.9 MB/s eta 0:00:02
# ...

# %%
import pandas as pd

csv_file = pd.read_csv("C:/Users/ARIT-Thailand/Downloads/titanic.csv")
print(csv_file)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
csv_file.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 810          811         0       3
# 446          447         1       2
# 599          600         1       1
# 270          271         0       1
# 24            25         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 810                        Alexander, Mr. William    male  26.0      0      0
# 446             Mellinger, Miss. Madeleine Violet  female  13.0      0      1
# 599  Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")    male  49.0      1      0
# 270                         Cairns, Mr. Alexander    male   NaN      0      0
# 24                  Palsson, Miss. Torborg Danira  female   8.0      3      1
#
#        Ticket     Fare Cabin Embarked
# 810      3474   7.8875   NaN        S
# 446    250644  19.5000   NaN        S
# 599  PC 17485  56.9292   A20        C
# 270    113798  31.0000   NaN        S
# 24     349909  21.0750   NaN        S

# %%
from forex_python.converter import CurrencyRates
c = CurrencyRates()
c.get_rate('USD', 'INR')
# Out:
# ---------------------------------------------------------------------------
# RatesNotAvailableError                    Traceback (most recent call last)
# Cell In[14], line 3
#       1 from forex_python.converter import CurrencyRates
#       2 c = CurrencyRates()
# ----> 3 c.get_rate('USD', 'INR')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\forex_python\converter.py:79, in CurrencyRates.get_rate(self, base_cur, dest_cur, date_obj)
#      76         raise RatesNotAvailableError("Currency Rate {0} => {1} not available for Date {2}".format(
#      77             base_cur, dest_cur, date_str))
#      78     return rate
# ---> 79 raise RatesNotAvailableError("Currency Rates Source Not Ready")
#
# RatesNotAvailableError: Currency Rates Source Not Ready

# %%
# !pip install forex-python
# Out:
# ...
#    ---------------------------------------- 0.0/75.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/75.4 kB ? eta -:--:--
#    -------------------------------------- - 71.7/75.4 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 75.4/75.4 kB 1.1 MB/s eta 0:00:00
# ...
